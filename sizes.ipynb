# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
tdf = pd.read_csv("test.csv")

# %%
sns.jointplot(df.imgheight, df.imgwidth)
sns.jointplot(tdf.imgheight, tdf.imgwidth)

# %%
sns.distplot(df.height/df.width)
sns.distplot(tdf.height/tdf.width)
plt.xlim(0,10)
print()

# %%
df.plot.hexbin(x="height", y="width", sharex=False, colormap="plasma") #, figsize=(15,15))

# %%
tdf.plot.hexbin(x="height", y="width", sharex=False, colormap="plasma") #, figsize=(15,15))

# %%
sns.jointplot(df.height, df.width)#, xlim=(0,200), ylim=(0,100))
sns.jointplot(tdf.height, tdf.width)#, xlim=(0,200), ylim=(0,100))

# %% [markdown]
# ### Bbox aspect ratios
# W:H = 1:1, 1:2, 1:3, 1:4, 1:5
#
# ### Bbox sizes
# W = 10, 20, 40, 60, 80, 125
#
# ### Better sizes
# WxH = (10,10), (10,20), (10,30), (10,40), (10,50), (20,20), (20,40), (20,60), (20,80), (20,100), (40,40), (40,80), (40,120), (60,60), (60,90), (60,120), (80,100), (80,160), (100,120), (100,200)
#
# WxH = (20,20), (20,40), (20,60), (40,40), (40,60), (40,80), (40,100), (40,120), (60,60), (60,80), (60,100), (60,120), (60,140), (80,100), (80,120), (80,140), (80,160), (100,120), (100,140), (120, 120), (120, 150), (120,200)
#
# Final WxH = (10,20), (10,30), (10,40), (20,20), (20,40), (20,60), (40,40), (40,60), (40,80), (40,100), (40,120), (60,60), (60,80), (60,100), (60,120), (60,140), (80,100), (80,120), (80,140), (80,160), (100,120), (100,140), (120, 120), (120, 150), (120,200)
